# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://pytorch.org/docs/stable/sparse.html

# %% [markdown]
# * review_classify.py에서 sparse matrix를 tensor로 바꾸려고 했는데 torch.tensor() 로는 안되었다. 그래서 새로운 방법을 찾아보았다.

# %% [markdown]
# ![image.png](attachment:image.png)
